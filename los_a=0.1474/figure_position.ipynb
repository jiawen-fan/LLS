# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
def unPackRawFile(raw_path):
    y = np.loadtxt(raw_path,comments = " ")
    return y

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(248.853,503.881,306.812)
